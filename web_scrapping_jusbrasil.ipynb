# %%
import time
import re
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
#import sys
#reload(sys)
#sys.setdefaultencoding('utf-8')
compilado = ''
   #browser.get("https://www.jusbrasil.com.br/home")

#time.sleep(30)
nrs=['cod_proc1',
'cod_proc2']
for i in range(782,len(nrs)):
    try:
        #Entre
        browser = webdriver.Chrome(r'.\chromedriver.exe')
        browser.get("https://www.jusbrasil.com.br" + "/consulta-processual/busca?q=" + nrs[i])
        #time.sleep(5)
        #loga
        #browser.find_element_by_xpath('//button[normalize-space()="Desbloquear andamentos"]').click()
        #browser.find_element_by_xpath("//span[@class='ClaimValue-cta link']").click()


        #time.sleep(3)
        #browser.find_element_by_xpath("//a[@class='sign-up-footer-link sign-up-login-link']").click()

        #time.sleep(3)
 
        #time.sleep(3)
        #browser.find_element_by_xpath("//div[@class='login-step login-account-found-step']").click()
        #time.sleep(1)
        #Join = input('y/n').lower()

        #time.sleep(2)

        #no_of_pagedowns =80
        #elem = browser.find_element_by_tag_name("body")



        #while no_of_pagedowns:
         #   elem.send_keys(Keys.PAGE_DOWN)
          #  time.sleep(0.2)
           # no_of_pagedowns-=1
            
            
        #time.sleep(1)
        #browser.find_element_by_xpath('//a[normalize-space()="Ok, entendi"]').click()
            
        SCROLL_PAUSE_TIME = 1
    
        # Get scroll height
        last_height = browser.execute_script("return document.body.scrollHeight")

        while True:
            # Scroll down to bottom
            browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

            # Wait to load page
            time.sleep(SCROLL_PAUSE_TIME)

            # Calculate new scroll height and compare with last scroll height
            new_height = browser.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
            
        time.sleep(1)
        #post_elems = browser.find_elements_by_class_name("LawsuitTimeline-date-absolute")
        
        post_elems2 = browser.find_elements_by_class_name("LawsuitTimeline-group")
        post_elems2 = browser.find_elements_by_class_name("LawsuitTimeline-group")
        #post_elems2 = browser.find_elements_by_class_name("InfiniteList LawsuitTimeline-list") 
        textao = ''
        time.sleep(1)
        for post in post_elems2:
            textao = textao + '\n' + post.text + '\n'
        time.sleep(1)
        regex = re.compile(r'.*')

        for line in textao.split('\n'):
            if regex.match(line):
                #print(nrs[i] + " - " + line)
                compilado =  compilado + '\n'+ nrs[i] + " - "  + line + '\n'
                
        f = open(r".\compilado.txt", "a",encoding='utf-8')
        f.write(compilado)
        compilado = ''
        browser.quit() 
        print(i)
    except Exception as e :
        print(e)
        browser.quit()
        pass
       
print(compilado)

import pandas as pd
import io
df = pd.read_excel(r"entrada.xlsx",encoding = "iso-8859-1", sep="\n")

df.to_excel(r'saida/output.xlsx',encoding='utf-8')
df
